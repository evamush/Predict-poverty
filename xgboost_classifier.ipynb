# %%
import os

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

% matplotlib inline

# %%
PATH = os.path.join( 'data', 'processed')

# %%
data_path = {'A': {'train': os.path.join(PATH, 'A', 'A_hhold_train.csv'),
                   'test' : os.path.join(PATH, 'A', 'A_hhold_test.csv')},
             'B': {'train': os.path.join(PATH, 'B', 'B_hhold_train.csv'),
                   'test' : os.path.join(PATH, 'B', 'B_hhold_test.csv')},
             'C': {'train': os.path.join(PATH, 'C', 'C_hhold_train.csv'), 
                    'test': os.path.join(PATH, 'C', 'C_hhold_test.csv')}}

# %%
a_train = pd.read_csv(data_path['A']['train'], index_col='id')
b_train = pd.read_csv(data_path['B']['train'], index_col='id')
c_train = pd.read_csv(data_path['C']['train'], index_col='id')

# %%
# Standardize features
def standardize(df, numeric_only=True):
    numeric = df.select_dtypes(include=['int64', 'float64'])
    
    # subtracy mean and divide by std
    df[numeric.columns] = (numeric - numeric.mean()) / numeric.std()
    
    return df
    

def pre_process_data(df, enforce_cols=None):
    print("Input shape:\t{}".format(df.shape))
        

    df = standardize(df)
    print("After standardization {}".format(df.shape))
        
    # create dummy variables for categoricals
    df = pd.get_dummies(df)
    print("After converting categoricals:\t{}".format(df.shape))
    

    # match test set and training set columns
    if enforce_cols is not None:
        to_drop = np.setdiff1d(df.columns, enforce_cols)
        to_add = np.setdiff1d(enforce_cols, df.columns)

        df.drop(to_drop, axis=1, inplace=True)
        df = df.assign(**{c: 0 for c in to_add})
    
    df.fillna(-999, inplace=True)
    
    return df

# %%
print("Country A")
aX_train = pre_process_data(a_train.drop('poor', axis=1))
ay_train = np.ravel(a_train.poor)

print("\nCountry B")
bX_train = pre_process_data(b_train.drop('poor', axis=1))
by_train = np.ravel(b_train.poor)

print("\nCountry C")
cX_train = pre_process_data(c_train.drop('poor', axis=1))
cy_train = np.ravel(c_train.poor)
# Out:
# Country A
# Input shape:	(8203, 344)
# After standardization (8203, 344)
# After converting categoricals:	(8203, 859)
#
# Country B
# Input shape:	(3255, 441)
# After standardization (3255, 441)
# After converting categoricals:	(3255, 1432)
#
# Country C
# Input shape:	(6469, 163)
# After standardization (6469, 163)
# After converting categoricals:	(6469, 795)

# %% [markdown]
# 删去部分无用的数据

# %%
aX_train = aX_train.drop(['country_A'],axis=1)
bX_train = bX_train.drop(['country_B'],axis=1)
cX_train = cX_train.drop(['country_C'],axis=1)

# %%
aX_train.head()
# Out:
#        nEsgxvAq  OMtioXZZ  YFMZwKrU  TiwRslOh  wBXbHZmp_DkQlr  wBXbHZmp_JhtDR  \
# id
# 46107 -1.447160  0.325746  1.099716 -0.628045               0               1
# 82739 -0.414625 -0.503468 -0.016050  0.713467               0               1
# 9646   0.617910 -0.503468 -0.016050 -0.628045               0               1
# 10975  0.617910 -1.332682 -1.131816  0.713467               0               1
# 16463  0.617910  0.325746 -1.131816 -0.180874               0               1
#
#        SlDKnCuu_GUusz  SlDKnCuu_alLXR  KAJOWiiw_BIZns  KAJOWiiw_TuovO  \
# id
# 46107               1               0               0               1
# 82739               1               0               0               1
# 9646                1               0               1               0
# 10975               1               0               0               1
# 16463               0               1               0               1
#
#             ...        JCDeZBXq_LPtkN  JCDeZBXq_UyAms  HGPWuGlV_WKNwg  \
# id          ...
# 46107       ...                     1               0               0
# 82739       ...                     0               1               0
# 9646        ...                     0               1               0
# 10975       ...                     0               1               0
# 16463       ...                     0               1               0
#
#        HGPWuGlV_vkbkA  GDUPaBQs_qCEuA  GDUPaBQs_qQxrL  WuwrCsIY_AITFl  \
# id
# 46107               1               0               1               1
# 82739               1               0               1               1
# 9646                1               0               1               1
# 10975               1               0               1               1
# 16463               1               0               1               0
#
#        WuwrCsIY_GAZGl  AlDbXTlZ_aQeIm  AlDbXTlZ_cecIq
# id
# 46107               0               1               0
# 82739               0               0               1
# 9646                0               0               1
# 10975               0               0               1
# 16463               1               1               0
#
# [5 rows x 858 columns]

# %%
cX_train.head()
# Out:
#        LhUIIEHQ  PNAiwXUz  jmsRIiqp  NONtAKOM  kLAQgdly  WWuPOkor  CtFxPQPT  \
# id
# 57211 -0.606739 -0.350340 -0.313847 -0.310077 -0.704307  0.524039  0.380397
# 62519 -0.606739  3.907434 -0.313847  0.249445 -0.390493  0.524039 -3.296468
# 11614  0.742520 -0.299653  0.449989  0.808967  1.004237  0.524039  0.380397
# 6470   0.742520 -0.350340 -1.077683  0.808967  1.004237  0.524039  0.292852
# 33558  0.742520  0.004474  0.449989 -0.310077 -0.094113 -1.142633  0.424169
#
#        GIwNbAsH  qLDzvjiU  detlNNFh       ...        obIQUcpS_YXwVA  \
# id                                        ...
# 57211  0.026222 -0.249567 -0.127064       ...                     1
# 62519  0.026222 -0.249567 -0.127064       ...                     0
# 11614 -0.444972  0.541055 -0.127064       ...                     1
# 6470  -0.444972 -1.040189 -0.127064       ...                     1
# 33558 -0.444972 -0.249567  0.184764       ...                     0
#
#        lAvdypjD_SnGME  lAvdypjD_UUKOE  lAvdypjD_gWylU  lAvdypjD_jSoky  \
# id
# 57211               0               0               0               1
# 62519               0               0               0               1
# 11614               0               0               0               1
# 6470                0               0               0               1
# 33558               0               0               0               1
#
#        ARWytYMz_NwjRA  ARWytYMz_herus  eqJPmiPb_Rrpos  eqJPmiPb_mORJu  \
# id
# 57211               1               0               0               0
# 62519               1               0               0               0
# 11614               1               0               0               0
# 6470                1               0               0               0
# 33558               0               1               0               0
#
#        eqJPmiPb_wnPqZ
# id
# 57211               1
# 62519               1
# 11614               1
# 6470                1
# 33558               1
#
# [5 rows x 794 columns]

# %%
import xgboost as xgb
from sklearn.cross_validation import StratifiedKFold
from sklearn.grid_search import GridSearchCV

# %% [markdown]
# 通过crossvalidation来做参数筛选

# %%
xgb_model = xgb.XGBClassifier()
parameters = {'nthread':[4], 
              'objective':['binary:logistic'],
              'learning_rate':[0.05],
              'max_depth':[10,11,12],
              'min_child_weight':[11],
              'silent':[1],
              'subsample':[0.8],
              'colsample_bytree':[0.7],
              'n_estimators':[50,70,100],
              'missing':[-999],
              'seed':[1337]
             }

# %%
model_A = GridSearchCV(xgb_model, param_grid=parameters, n_jobs=5,
                       cv=StratifiedKFold(ay_train, n_folds=5,shuffle=True),
                       scoring='roc_auc',
                       verbose=2,
                       refit=True)
model_A.fit(aX_train, ay_train)
# Out:
# Fitting 5 folds for each of 9 candidates, totalling 45 fits
# [CV] colsample_bytree=0.7, learning_rate=0.05, max_depth=10, min_child_weight=11, missing=-999, n_estimators=50, nthread=4, objective=binary:logistic, seed=1337, silent=1, subsample=0.8
# [CV] colsample_bytree=0.7, learning_rate=0.05, max_depth=10, min_child_weight=11, missing=-999, n_estimators=50, nthread=4, objective=binary:logistic, seed=1337, silent=1, subsample=0.8
# [CV] colsample_bytree=0.7, learning_rate=0.05, max_depth=10, min_child_weight=11, missing=-999, n_estimators=50, nthread=4, objective=binary:logistic, seed=1337, silent=1, subsample=0.8
# [CV] colsample_bytree=0.7, learning_rate=0.05, max_depth=10, min_child_weight=11, missing=-999, n_estimators=50, nthread=4, objective=binary:logistic, seed=1337, silent=1, subsample=0.8
# [CV] colsample_bytree=0.7, learning_rate=0.05, max_depth=10, min_child_weight=11, missing=-999, n_estimators=50, nthread=4, objective=binary:logistic, seed=1337, silent=1, subsample=0.8
# [CV]  colsample_bytree=0.7, learning_rate=0.05, max_depth=10, min_child_weight=11, missing=-999, n_estimators=50, nthread=4, objective=binary:logistic, seed=1337, silent=1, subsample=0.8 -  48.0s
# [CV] colsample_bytree=0.7, learning_rate=0.05, max_depth=10, min_child_weight=11, missing=-999, n_estimators=70, nthread=4, objective=binary:logistic, seed=1337, silent=1, subsample=0.8
# [CV]  colsample_bytree=0.7, learning_rate=0.05, max_depth=10, min_child_weight=11, missing=-999, n_estimators=50, nthread=4, objective=binary:logistic, seed=1337, silent=1, subsample=0.8 -  48.2s
# [CV] colsample_bytree=0.7, learning_rate=0.05, max_depth=10, min_child_weight=11, missing=-999, n_estimators=70, nthread=4, objective=binary:logistic, seed=1337, silent=1, subsample=0.8
# [CV]  colsample_bytree=0.7, learning_rate=0.05, max_depth=10, min_child_weight=11, missing=-999, n_estimators=50, nthread=4, objective=binary:logistic, seed=1337, silent=1, subsample=0.8 -  48.2s
# [CV] colsample_bytree=0.7, learning_rate=0.05, max_depth=10, min_child_weight=11, missing=-999, n_estimators=70, nthread=4, objective=binary:logistic, seed=1337, silent=1, subsample=0.8
# [CV]  colsample_bytree=0.7, learning_rate=0.05, max_depth=10, min_child_weight=11, missing=-999, n_estimators=50, nthread=4, objective=binary:logistic, seed=1337, silent=1, subsample=0.8 -  48.2s
# [CV] colsample_bytree=0.7, learning_rate=0.05, max_depth=10, min_child_weight=11, missing=-999, n_estimators=70, nthread=4, objective=binary:logistic, seed=1337, silent=1, subsample=0.8
# [CV]  colsample_bytree=0.7, learning_rate=0.05, max_depth=10, min_child_weight=11, missing=-999, n_estimators=50, nthread=4, objective=binary:logistic, seed=1337, silent=1, subsample=0.8 -  48.4s
# [CV] colsample_bytree=0.7, learning_rate=0.05, max_depth=10, min_child_weight=11, missing=-999, n_estimators=70, nthread=4, objective=binary:logistic, seed=1337, silent=1, subsample=0.8
# [CV]  colsample_bytree=0.7, learning_rate=0.05, max_depth=10, min_child_weight=11, missing=-999, n_estimators=70, nthread=4, objective=binary:logistic, seed=1337, silent=1, subsample=0.8 -  56.9s
# [CV] colsample_bytree=0.7, learning_rate=0.05, max_depth=10, min_child_weight=11, missing=-999, n_estimators=100, nthread=4, objective=binary:logistic, seed=1337, silent=1, subsample=0.8
# [CV]  colsample_bytree=0.7, learning_rate=0.05, max_depth=10, min_child_weight=11, missing=-999, n_estimators=70, nthread=4, objective=binary:logistic, seed=1337, silent=1, subsample=0.8 -  57.3s
# [CV] colsample_bytree=0.7, learning_rate=0.05, max_depth=10, min_child_weight=11, missing=-999, n_estimators=100, nthread=4, objective=binary:logistic, seed=1337, silent=1, subsample=0.8
# [CV]  colsample_bytree=0.7, learning_rate=0.05, max_depth=10, min_child_weight=11, missing=-999, n_estimators=70, nthread=4, objective=binary:logistic, seed=1337, silent=1, subsample=0.8 -  57.2s
# [CV]  colsample_bytree=0.7, learning_rate=0.05, max_depth=10, min_child_weight=11, missing=-999, n_estimators=70, nthread=4, objective=binary:logistic, seed=1337, silent=1, subsample=0.8 -  57.4s
# [CV] colsample_bytree=0.7, learning_rate=0.05, max_depth=10, min_child_weight=11, missing=-999, n_estimators=100, nthread=4, objective=binary:logistic, seed=1337, silent=1, subsample=0.8
# [CV] colsample_bytree=0.7, learning_rate=0.05, max_depth=10, min_child_weight=11, missing=-999, n_estimators=100, nthread=4, objective=binary:logistic, seed=1337, silent=1, subsample=0.8
# [CV]  colsample_bytree=0.7, learning_rate=0.05, max_depth=10, min_child_weight=11, missing=-999, n_estimators=70, nthread=4, objective=binary:logistic, seed=1337, silent=1, subsample=0.8 -  57.4s
# [CV] colsample_bytree=0.7, learning_rate=0.05, max_depth=10, min_child_weight=11, missing=-999, n_estimators=100, nthread=4, objective=binary:logistic, seed=1337, silent=1, subsample=0.8
# [CV]  colsample_bytree=0.7, learning_rate=0.05, max_depth=10, min_child_weight=11, missing=-999, n_estimators=100, nthread=4, objective=binary:logistic, seed=1337, silent=1, subsample=0.8 - 1.7min
# [CV] colsample_bytree=0.7, learning_rate=0.05, max_depth=11, min_child_weight=11, missing=-999, n_estimators=50, nthread=4, objective=binary:logistic, seed=1337, silent=1, subsample=0.8
# [CV]  colsample_bytree=0.7, learning_rate=0.05, max_depth=10, min_child_weight=11, missing=-999, n_estimators=100, nthread=4, objective=binary:logistic, seed=1337, silent=1, subsample=0.8 - 1.7min
# [CV] colsample_bytree=0.7, learning_rate=0.05, max_depth=11, min_child_weight=11, missing=-999, n_estimators=50, nthread=4, objective=binary:logistic, seed=1337, silent=1, subsample=0.8
# [CV]  colsample_bytree=0.7, learning_rate=0.05, max_depth=10, min_child_weight=11, missing=-999, n_estimators=100, nthread=4, objective=binary:logistic, seed=1337, silent=1, subsample=0.8 - 1.7min
# [CV]  colsample_bytree=0.7, learning_rate=0.05, max_depth=10, min_child_weight=11, missing=-999, n_estimators=100, nthread=4, objective=binary:logistic, seed=1337, silent=1, subsample=0.8 - 1.7min
# [CV] colsample_bytree=0.7, learning_rate=0.05, max_depth=11, min_child_weight=11, missing=-999, n_estimators=50, nthread=4, objective=binary:logistic, seed=1337, silent=1, subsample=0.8
# [CV] colsample_bytree=0.7, learning_rate=0.05, max_depth=11, min_child_weight=11, missing=-999, n_estimators=50, nthread=4, objective=binary:logistic, seed=1337, silent=1, subsample=0.8
# [CV]  colsample_bytree=0.7, learning_rate=0.05, max_depth=10, min_child_weight=11, missing=-999, n_estimators=100, nthread=4, objective=binary:logistic, seed=1337, silent=1, subsample=0.8 - 1.7min
# [CV] colsample_bytree=0.7, learning_rate=0.05, max_depth=11, min_child_weight=11, missing=-999, n_estimators=50, nthread=4, objective=binary:logistic, seed=1337, silent=1, subsample=0.8
# [CV]  colsample_bytree=0.7, learning_rate=0.05, max_depth=11, min_child_weight=11, missing=-999, n_estimators=50, nthread=4, objective=binary:logistic, seed=1337, silent=1, subsample=0.8 -  39.2s
# [CV] colsample_bytree=0.7, learning_rate=0.05, max_depth=11, min_child_weight=11, missing=-999, n_estimators=70, nthread=4, objective=binary:logistic, seed=1337, silent=1, subsample=0.8
# [CV]  colsample_bytree=0.7, learning_rate=0.05, max_depth=11, min_child_weight=11, missing=-999, n_estimators=50, nthread=4, objective=binary:logistic, seed=1337, silent=1, subsample=0.8 -  39.2s
# [CV] colsample_bytree=0.7, learning_rate=0.05, max_depth=11, min_child_weight=11, missing=-999, n_estimators=70, nthread=4, objective=binary:logistic, seed=1337, silent=1, subsample=0.8
# [CV]  colsample_bytree=0.7, learning_rate=0.05, max_depth=11, min_child_weight=11, missing=-999, n_estimators=50, nthread=4, objective=binary:logistic, seed=1337, silent=1, subsample=0.8 -  39.0s
# [CV]  colsample_bytree=0.7, learning_rate=0.05, max_depth=11, min_child_weight=11, missing=-999, n_estimators=50, nthread=4, objective=binary:logistic, seed=1337, silent=1, subsample=0.8 -  39.0s
# [CV] colsample_bytree=0.7, learning_rate=0.05, max_depth=11, min_child_weight=11, missing=-999, n_estimators=70, nthread=4, objective=binary:logistic, seed=1337, silent=1, subsample=0.8
# [CV] colsample_bytree=0.7, learning_rate=0.05, max_depth=11, min_child_weight=11, missing=-999, n_estimators=70, nthread=4, objective=binary:logistic, seed=1337, silent=1, subsample=0.8
# [CV]  colsample_bytree=0.7, learning_rate=0.05, max_depth=11, min_child_weight=11, missing=-999, n_estimators=50, nthread=4, objective=binary:logistic, seed=1337, silent=1, subsample=0.8 -  38.7s
# [CV] colsample_bytree=0.7, learning_rate=0.05, max_depth=11, min_child_weight=11, missing=-999, n_estimators=70, nthread=4, objective=binary:logistic, seed=1337, silent=1, subsample=0.8
# [CV]  colsample_bytree=0.7, learning_rate=0.05, max_depth=11, min_child_weight=11, missing=-999, n_estimators=70, nthread=4, objective=binary:logistic, seed=1337, silent=1, subsample=0.8 - 1.0min
# [CV]  colsample_bytree=0.7, learning_rate=0.05, max_depth=11, min_child_weight=11, missing=-999, n_estimators=70, nthread=4, objective=binary:logistic, seed=1337, silent=1, subsample=0.8 - 1.0min
# [CV] colsample_bytree=0.7, learning_rate=0.05, max_depth=11, min_child_weight=11, missing=-999, n_estimators=100, nthread=4, objective=binary:logistic, seed=1337, silent=1, subsample=0.8
# [CV] colsample_bytree=0.7, learning_rate=0.05, max_depth=11, min_child_weight=11, missing=-999, n_estimators=100, nthread=4, objective=binary:logistic, seed=1337, silent=1, subsample=0.8
# [CV]  colsample_bytree=0.7, learning_rate=0.05, max_depth=11, min_child_weight=11, missing=-999, n_estimators=70, nthread=4, objective=binary:logistic, seed=1337, silent=1, subsample=0.8 - 1.1min
# [CV] colsample_bytree=0.7, learning_rate=0.05, max_depth=11, min_child_weight=11, missing=-999, n_estimators=100, nthread=4, objective=binary:logistic, seed=1337, silent=1, subsample=0.8
# [CV]  colsample_bytree=0.7, learning_rate=0.05, max_depth=11, min_child_weight=11, missing=-999, n_estimators=70, nthread=4, objective=binary:logistic, seed=1337, silent=1, subsample=0.8 - 1.1min
# [CV] colsample_bytree=0.7, learning_rate=0.05, max_depth=11, min_child_weight=11, missing=-999, n_estimators=100, nthread=4, objective=binary:logistic, seed=1337, silent=1, subsample=0.8
# [CV]  colsample_bytree=0.7, learning_rate=0.05, max_depth=11, min_child_weight=11, missing=-999, n_estimators=70, nthread=4, objective=binary:logistic, seed=1337, silent=1, subsample=0.8 - 1.1min
# [CV] colsample_bytree=0.7, learning_rate=0.05, max_depth=11, min_child_weight=11, missing=-999, n_estimators=100, nthread=4, objective=binary:logistic, seed=1337, silent=1, subsample=0.8
# [CV]  colsample_bytree=0.7, learning_rate=0.05, max_depth=11, min_child_weight=11, missing=-999, n_estimators=100, nthread=4, objective=binary:logistic, seed=1337, silent=1, subsample=0.8 - 1.6min
# [CV] colsample_bytree=0.7, learning_rate=0.05, max_depth=12, min_child_weight=11, missing=-999, n_estimators=50, nthread=4, objective=binary:logistic, seed=1337, silent=1, subsample=0.8
# [CV]  colsample_bytree=0.7, learning_rate=0.05, max_depth=11, min_child_weight=11, missing=-999, n_estimators=100, nthread=4, objective=binary:logistic, seed=1337, silent=1, subsample=0.8 - 1.6min
# [CV] colsample_bytree=0.7, learning_rate=0.05, max_depth=12, min_child_weight=11, missing=-999, n_estimators=50, nthread=4, objective=binary:logistic, seed=1337, silent=1, subsample=0.8
# [CV]  colsample_bytree=0.7, learning_rate=0.05, max_depth=11, min_child_weight=11, missing=-999, n_estimators=100, nthread=4, objective=binary:logistic, seed=1337, silent=1, subsample=0.8 - 1.6min
# [CV] colsample_bytree=0.7, learning_rate=0.05, max_depth=12, min_child_weight=11, missing=-999, n_estimators=50, nthread=4, objective=binary:logistic, seed=1337, silent=1, subsample=0.8
# [CV]  colsample_bytree=0.7, learning_rate=0.05, max_depth=11, min_child_weight=11, missing=-999, n_estimators=100, nthread=4, objective=binary:logistic, seed=1337, silent=1, subsample=0.8 - 1.6min
# [CV] colsample_bytree=0.7, learning_rate=0.05, max_depth=12, min_child_weight=11, missing=-999, n_estimators=50, nthread=4, objective=binary:logistic, seed=1337, silent=1, subsample=0.8
# [CV]  colsample_bytree=0.7, learning_rate=0.05, max_depth=11, min_child_weight=11, missing=-999, n_estimators=100, nthread=4, objective=binary:logistic, seed=1337, silent=1, subsample=0.8 - 1.6min
# [CV] colsample_bytree=0.7, learning_rate=0.05, max_depth=12, min_child_weight=11, missing=-999, n_estimators=50, nthread=4, objective=binary:logistic, seed=1337, silent=1, subsample=0.8
# [CV]  colsample_bytree=0.7, learning_rate=0.05, max_depth=12, min_child_weight=11, missing=-999, n_estimators=50, nthread=4, objective=binary:logistic, seed=1337, silent=1, subsample=0.8 -  45.1s
# [CV] colsample_bytree=0.7, learning_rate=0.05, max_depth=12, min_child_weight=11, missing=-999, n_estimators=70, nthread=4, objective=binary:logistic, seed=1337, silent=1, subsample=0.8
# [CV]  colsample_bytree=0.7, learning_rate=0.05, max_depth=12, min_child_weight=11, missing=-999, n_estimators=50, nthread=4, objective=binary:logistic, seed=1337, silent=1, subsample=0.8 -  45.9s
# [Parallel(n_jobs=5)]: Done  31 tasks      | elapsed:  7.5min
# [CV] colsample_bytree=0.7, learning_rate=0.05, max_depth=12, min_child_weight=11, missing=-999, n_estimators=70, nthread=4, objective=binary:logistic, seed=1337, silent=1, subsample=0.8
# [CV]  colsample_bytree=0.7, learning_rate=0.05, max_depth=12, min_child_weight=11, missing=-999, n_estimators=50, nthread=4, objective=binary:logistic, seed=1337, silent=1, subsample=0.8 -  45.6s
# [CV] colsample_bytree=0.7, learning_rate=0.05, max_depth=12, min_child_weight=11, missing=-999, n_estimators=70, nthread=4, objective=binary:logistic, seed=1337, silent=1, subsample=0.8
# [CV]  colsample_bytree=0.7, learning_rate=0.05, max_depth=12, min_child_weight=11, missing=-999, n_estimators=50, nthread=4, objective=binary:logistic, seed=1337, silent=1, subsample=0.8 -  45.9s
# [CV] colsample_bytree=0.7, learning_rate=0.05, max_depth=12, min_child_weight=11, missing=-999, n_estimators=70, nthread=4, objective=binary:logistic, seed=1337, silent=1, subsample=0.8
# [CV]  colsample_bytree=0.7, learning_rate=0.05, max_depth=12, min_child_weight=11, missing=-999, n_estimators=50, nthread=4, objective=binary:logistic, seed=1337, silent=1, subsample=0.8 -  45.5s
# [CV] colsample_bytree=0.7, learning_rate=0.05, max_depth=12, min_child_weight=11, missing=-999, n_estimators=70, nthread=4, objective=binary:logistic, seed=1337, silent=1, subsample=0.8
# [CV]  colsample_bytree=0.7, learning_rate=0.05, max_depth=12, min_child_weight=11, missing=-999, n_estimators=70, nthread=4, objective=binary:logistic, seed=1337, silent=1, subsample=0.8 - 1.1min
# [CV]  colsample_bytree=0.7, learning_rate=0.05, max_depth=12, min_child_weight=11, missing=-999, n_estimators=70, nthread=4, objective=binary:logistic, seed=1337, silent=1, subsample=0.8 - 1.1min
# [CV] colsample_bytree=0.7, learning_rate=0.05, max_depth=12, min_child_weight=11, missing=-999, n_estimators=100, nthread=4, objective=binary:logistic, seed=1337, silent=1, subsample=0.8
# [CV] colsample_bytree=0.7, learning_rate=0.05, max_depth=12, min_child_weight=11, missing=-999, n_estimators=100, nthread=4, objective=binary:logistic, seed=1337, silent=1, subsample=0.8
# [CV]  colsample_bytree=0.7, learning_rate=0.05, max_depth=12, min_child_weight=11, missing=-999, n_estimators=70, nthread=4, objective=binary:logistic, seed=1337, silent=1, subsample=0.8 - 1.1min
# [CV] colsample_bytree=0.7, learning_rate=0.05, max_depth=12, min_child_weight=11, missing=-999, n_estimators=100, nthread=4, objective=binary:logistic, seed=1337, silent=1, subsample=0.8
# [CV]  colsample_bytree=0.7, learning_rate=0.05, max_depth=12, min_child_weight=11, missing=-999, n_estimators=70, nthread=4, objective=binary:logistic, seed=1337, silent=1, subsample=0.8 - 1.1min
# [CV] colsample_bytree=0.7, learning_rate=0.05, max_depth=12, min_child_weight=11, missing=-999, n_estimators=100, nthread=4, objective=binary:logistic, seed=1337, silent=1, subsample=0.8
# [CV]  colsample_bytree=0.7, learning_rate=0.05, max_depth=12, min_child_weight=11, missing=-999, n_estimators=70, nthread=4, objective=binary:logistic, seed=1337, silent=1, subsample=0.8 - 1.1min
# [CV] colsample_bytree=0.7, learning_rate=0.05, max_depth=12, min_child_weight=11, missing=-999, n_estimators=100, nthread=4, objective=binary:logistic, seed=1337, silent=1, subsample=0.8
# [CV]  colsample_bytree=0.7, learning_rate=0.05, max_depth=12, min_child_weight=11, missing=-999, n_estimators=100, nthread=4, objective=binary:logistic, seed=1337, silent=1, subsample=0.8 - 1.7min
# [CV]  colsample_bytree=0.7, learning_rate=0.05, max_depth=12, min_child_weight=11, missing=-999, n_estimators=100, nthread=4, objective=binary:logistic, seed=1337, silent=1, subsample=0.8 - 1.7min
# [CV]  colsample_bytree=0.7, learning_rate=0.05, max_depth=12, min_child_weight=11, missing=-999, n_estimators=100, nthread=4, objective=binary:logistic, seed=1337, silent=1, subsample=0.8 - 1.7min
# [CV]  colsample_bytree=0.7, learning_rate=0.05, max_depth=12, min_child_weight=11, missing=-999, n_estimators=100, nthread=4, objective=binary:logistic, seed=1337, silent=1, subsample=0.8 - 1.7min
# [CV]  colsample_bytree=0.7, learning_rate=0.05, max_depth=12, min_child_weight=11, missing=-999, n_estimators=100, nthread=4, objective=binary:logistic, seed=1337, silent=1, subsample=0.8 - 1.7min
# [Parallel(n_jobs=5)]: Done  45 out of  45 | elapsed: 10.3min finished
# GridSearchCV(cv=sklearn.cross_validation.StratifiedKFold(labels=[False False ...,  True False], n_folds=5, shuffle=True, random_state=None),
#        error_score='raise',
#        estimator=XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bytree=1, gamma=0, learning_rate=0.1, max_delta_step=0,
#        max_depth=3, min_child_weight=1, missing=None, n_estimators=100,
#        n_jobs=1, nthread=None, objective='binary:logistic', random_state=0,
#        reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#        silent=True, subsample=1),
#        fit_params={}, iid=True, n_jobs=5,
#        param_grid={'nthread': [4], 'objective': ['binary:logistic'], 'learning_rate': [0.05], 'max_depth': [10, 11, 12], 'min_child_weight': [11], 'silent': [1], 'subsample': [0.8], 'colsample_bytree': [0.7], 'n_estimators': [50, 70, 100], 'missing': [-999], 'seed': [1337]},
#        pre_dispatch='2*n_jobs', refit=True, scoring='roc_auc', verbose=2)

# %%
model_B = GridSearchCV(xgb_model, param_grid=parameters, n_jobs=5,
                       cv=StratifiedKFold(by_train, n_folds=5,shuffle=True),
                       scoring='roc_auc',
                       verbose=2,
                       refit=True)
model_B.fit(bX_train, by_train)
# Out:
# Fitting 5 folds for each of 9 candidates, totalling 45 fits
# [CV] colsample_bytree=0.7, learning_rate=0.05, max_depth=10, min_child_weight=11, missing=-999, n_estimators=50, nthread=4, objective=binary:logistic, seed=1337, silent=1, subsample=0.8
# [CV] colsample_bytree=0.7, learning_rate=0.05, max_depth=10, min_child_weight=11, missing=-999, n_estimators=50, nthread=4, objective=binary:logistic, seed=1337, silent=1, subsample=0.8
# [CV] colsample_bytree=0.7, learning_rate=0.05, max_depth=10, min_child_weight=11, missing=-999, n_estimators=50, nthread=4, objective=binary:logistic, seed=1337, silent=1, subsample=0.8
# [CV] colsample_bytree=0.7, learning_rate=0.05, max_depth=10, min_child_weight=11, missing=-999, n_estimators=50, nthread=4, objective=binary:logistic, seed=1337, silent=1, subsample=0.8
# [CV] colsample_bytree=0.7, learning_rate=0.05, max_depth=10, min_child_weight=11, missing=-999, n_estimators=50, nthread=4, objective=binary:logistic, seed=1337, silent=1, subsample=0.8
# [CV]  colsample_bytree=0.7, learning_rate=0.05, max_depth=10, min_child_weight=11, missing=-999, n_estimators=50, nthread=4, objective=binary:logistic, seed=1337, silent=1, subsample=0.8 -  19.5s
# [CV] colsample_bytree=0.7, learning_rate=0.05, max_depth=10, min_child_weight=11, missing=-999, n_estimators=70, nthread=4, objective=binary:logistic, seed=1337, silent=1, subsample=0.8
# [CV]  colsample_bytree=0.7, learning_rate=0.05, max_depth=10, min_child_weight=11, missing=-999, n_estimators=50, nthread=4, objective=binary:logistic, seed=1337, silent=1, subsample=0.8 -  19.6s
# [CV] colsample_bytree=0.7, learning_rate=0.05, max_depth=10, min_child_weight=11, missing=-999, n_estimators=70, nthread=4, objective=binary:logistic, seed=1337, silent=1, subsample=0.8
# [CV]  colsample_bytree=0.7, learning_rate=0.05, max_depth=10, min_child_weight=11, missing=-999, n_estimators=50, nthread=4, objective=binary:logistic, seed=1337, silent=1, subsample=0.8 -  20.2s
# [CV] colsample_bytree=0.7, learning_rate=0.05, max_depth=10, min_child_weight=11, missing=-999, n_estimators=70, nthread=4, objective=binary:logistic, seed=1337, silent=1, subsample=0.8
# [CV]  colsample_bytree=0.7, learning_rate=0.05, max_depth=10, min_child_weight=11, missing=-999, n_estimators=50, nthread=4, objective=binary:logistic, seed=1337, silent=1, subsample=0.8 -  20.8s
# [CV] colsample_bytree=0.7, learning_rate=0.05, max_depth=10, min_child_weight=11, missing=-999, n_estimators=70, nthread=4, objective=binary:logistic, seed=1337, silent=1, subsample=0.8
# [CV]  colsample_bytree=0.7, learning_rate=0.05, max_depth=10, min_child_weight=11, missing=-999, n_estimators=50, nthread=4, objective=binary:logistic, seed=1337, silent=1, subsample=0.8 -  20.8s
# [CV] colsample_bytree=0.7, learning_rate=0.05, max_depth=10, min_child_weight=11, missing=-999, n_estimators=70, nthread=4, objective=binary:logistic, seed=1337, silent=1, subsample=0.8
# [CV]  colsample_bytree=0.7, learning_rate=0.05, max_depth=10, min_child_weight=11, missing=-999, n_estimators=70, nthread=4, objective=binary:logistic, seed=1337, silent=1, subsample=0.8 -  30.1s
# [CV] colsample_bytree=0.7, learning_rate=0.05, max_depth=10, min_child_weight=11, missing=-999, n_estimators=100, nthread=4, objective=binary:logistic, seed=1337, silent=1, subsample=0.8
# [CV]  colsample_bytree=0.7, learning_rate=0.05, max_depth=10, min_child_weight=11, missing=-999, n_estimators=70, nthread=4, objective=binary:logistic, seed=1337, silent=1, subsample=0.8 -  30.7s
# [CV] colsample_bytree=0.7, learning_rate=0.05, max_depth=10, min_child_weight=11, missing=-999, n_estimators=100, nthread=4, objective=binary:logistic, seed=1337, silent=1, subsample=0.8
# [CV]  colsample_bytree=0.7, learning_rate=0.05, max_depth=10, min_child_weight=11, missing=-999, n_estimators=70, nthread=4, objective=binary:logistic, seed=1337, silent=1, subsample=0.8 -  30.1s
# [CV] colsample_bytree=0.7, learning_rate=0.05, max_depth=10, min_child_weight=11, missing=-999, n_estimators=100, nthread=4, objective=binary:logistic, seed=1337, silent=1, subsample=0.8
# [CV]  colsample_bytree=0.7, learning_rate=0.05, max_depth=10, min_child_weight=11, missing=-999, n_estimators=70, nthread=4, objective=binary:logistic, seed=1337, silent=1, subsample=0.8 -  29.6s
# [CV] colsample_bytree=0.7, learning_rate=0.05, max_depth=10, min_child_weight=11, missing=-999, n_estimators=100, nthread=4, objective=binary:logistic, seed=1337, silent=1, subsample=0.8
# [CV]  colsample_bytree=0.7, learning_rate=0.05, max_depth=10, min_child_weight=11, missing=-999, n_estimators=70, nthread=4, objective=binary:logistic, seed=1337, silent=1, subsample=0.8 -  31.0s
# [CV] colsample_bytree=0.7, learning_rate=0.05, max_depth=10, min_child_weight=11, missing=-999, n_estimators=100, nthread=4, objective=binary:logistic, seed=1337, silent=1, subsample=0.8
# [CV]  colsample_bytree=0.7, learning_rate=0.05, max_depth=10, min_child_weight=11, missing=-999, n_estimators=100, nthread=4, objective=binary:logistic, seed=1337, silent=1, subsample=0.8 -  39.1s
# [CV] colsample_bytree=0.7, learning_rate=0.05, max_depth=11, min_child_weight=11, missing=-999, n_estimators=50, nthread=4, objective=binary:logistic, seed=1337, silent=1, subsample=0.8
# [CV]  colsample_bytree=0.7, learning_rate=0.05, max_depth=10, min_child_weight=11, missing=-999, n_estimators=100, nthread=4, objective=binary:logistic, seed=1337, silent=1, subsample=0.8 -  38.9s
# [CV] colsample_bytree=0.7, learning_rate=0.05, max_depth=11, min_child_weight=11, missing=-999, n_estimators=50, nthread=4, objective=binary:logistic, seed=1337, silent=1, subsample=0.8
# [CV]  colsample_bytree=0.7, learning_rate=0.05, max_depth=10, min_child_weight=11, missing=-999, n_estimators=100, nthread=4, objective=binary:logistic, seed=1337, silent=1, subsample=0.8 -  40.0s
# [CV] colsample_bytree=0.7, learning_rate=0.05, max_depth=11, min_child_weight=11, missing=-999, n_estimators=50, nthread=4, objective=binary:logistic, seed=1337, silent=1, subsample=0.8
# [CV]  colsample_bytree=0.7, learning_rate=0.05, max_depth=10, min_child_weight=11, missing=-999, n_estimators=100, nthread=4, objective=binary:logistic, seed=1337, silent=1, subsample=0.8 -  40.2s
# [CV] colsample_bytree=0.7, learning_rate=0.05, max_depth=11, min_child_weight=11, missing=-999, n_estimators=50, nthread=4, objective=binary:logistic, seed=1337, silent=1, subsample=0.8
# [CV]  colsample_bytree=0.7, learning_rate=0.05, max_depth=10, min_child_weight=11, missing=-999, n_estimators=100, nthread=4, objective=binary:logistic, seed=1337, silent=1, subsample=0.8 -  41.8s
# [CV] colsample_bytree=0.7, learning_rate=0.05, max_depth=11, min_child_weight=11, missing=-999, n_estimators=50, nthread=4, objective=binary:logistic, seed=1337, silent=1, subsample=0.8
# [CV]  colsample_bytree=0.7, learning_rate=0.05, max_depth=11, min_child_weight=11, missing=-999, n_estimators=50, nthread=4, objective=binary:logistic, seed=1337, silent=1, subsample=0.8 -  23.5s
# [CV] colsample_bytree=0.7, learning_rate=0.05, max_depth=11, min_child_weight=11, missing=-999, n_estimators=70, nthread=4, objective=binary:logistic, seed=1337, silent=1, subsample=0.8
# [CV]  colsample_bytree=0.7, learning_rate=0.05, max_depth=11, min_child_weight=11, missing=-999, n_estimators=50, nthread=4, objective=binary:logistic, seed=1337, silent=1, subsample=0.8 -  24.0s
# [CV] colsample_bytree=0.7, learning_rate=0.05, max_depth=11, min_child_weight=11, missing=-999, n_estimators=70, nthread=4, objective=binary:logistic, seed=1337, silent=1, subsample=0.8
# [CV]  colsample_bytree=0.7, learning_rate=0.05, max_depth=11, min_child_weight=11, missing=-999, n_estimators=50, nthread=4, objective=binary:logistic, seed=1337, silent=1, subsample=0.8 -  22.9s
# [CV] colsample_bytree=0.7, learning_rate=0.05, max_depth=11, min_child_weight=11, missing=-999, n_estimators=70, nthread=4, objective=binary:logistic, seed=1337, silent=1, subsample=0.8
# [CV]  colsample_bytree=0.7, learning_rate=0.05, max_depth=11, min_child_weight=11, missing=-999, n_estimators=50, nthread=4, objective=binary:logistic, seed=1337, silent=1, subsample=0.8 -  23.6s
# [CV] colsample_bytree=0.7, learning_rate=0.05, max_depth=11, min_child_weight=11, missing=-999, n_estimators=70, nthread=4, objective=binary:logistic, seed=1337, silent=1, subsample=0.8
# [CV]  colsample_bytree=0.7, learning_rate=0.05, max_depth=11, min_child_weight=11, missing=-999, n_estimators=50, nthread=4, objective=binary:logistic, seed=1337, silent=1, subsample=0.8 -  25.0s
# [CV] colsample_bytree=0.7, learning_rate=0.05, max_depth=11, min_child_weight=11, missing=-999, n_estimators=70, nthread=4, objective=binary:logistic, seed=1337, silent=1, subsample=0.8
# [CV]  colsample_bytree=0.7, learning_rate=0.05, max_depth=11, min_child_weight=11, missing=-999, n_estimators=70, nthread=4, objective=binary:logistic, seed=1337, silent=1, subsample=0.8 -  29.9s
# [CV] colsample_bytree=0.7, learning_rate=0.05, max_depth=11, min_child_weight=11, missing=-999, n_estimators=100, nthread=4, objective=binary:logistic, seed=1337, silent=1, subsample=0.8
# [CV]  colsample_bytree=0.7, learning_rate=0.05, max_depth=11, min_child_weight=11, missing=-999, n_estimators=70, nthread=4, objective=binary:logistic, seed=1337, silent=1, subsample=0.8 -  30.2s
# [CV] colsample_bytree=0.7, learning_rate=0.05, max_depth=11, min_child_weight=11, missing=-999, n_estimators=100, nthread=4, objective=binary:logistic, seed=1337, silent=1, subsample=0.8
# [CV]  colsample_bytree=0.7, learning_rate=0.05, max_depth=11, min_child_weight=11, missing=-999, n_estimators=70, nthread=4, objective=binary:logistic, seed=1337, silent=1, subsample=0.8 -  31.0s
# [CV] colsample_bytree=0.7, learning_rate=0.05, max_depth=11, min_child_weight=11, missing=-999, n_estimators=100, nthread=4, objective=binary:logistic, seed=1337, silent=1, subsample=0.8
# [CV]  colsample_bytree=0.7, learning_rate=0.05, max_depth=11, min_child_weight=11, missing=-999, n_estimators=70, nthread=4, objective=binary:logistic, seed=1337, silent=1, subsample=0.8 -  31.2s
# [CV] colsample_bytree=0.7, learning_rate=0.05, max_depth=11, min_child_weight=11, missing=-999, n_estimators=100, nthread=4, objective=binary:logistic, seed=1337, silent=1, subsample=0.8
# [CV]  colsample_bytree=0.7, learning_rate=0.05, max_depth=11, min_child_weight=11, missing=-999, n_estimators=70, nthread=4, objective=binary:logistic, seed=1337, silent=1, subsample=0.8 -  31.1s
# [CV] colsample_bytree=0.7, learning_rate=0.05, max_depth=11, min_child_weight=11, missing=-999, n_estimators=100, nthread=4, objective=binary:logistic, seed=1337, silent=1, subsample=0.8
# [CV]  colsample_bytree=0.7, learning_rate=0.05, max_depth=11, min_child_weight=11, missing=-999, n_estimators=100, nthread=4, objective=binary:logistic, seed=1337, silent=1, subsample=0.8 -  48.2s
# [CV] colsample_bytree=0.7, learning_rate=0.05, max_depth=12, min_child_weight=11, missing=-999, n_estimators=50, nthread=4, objective=binary:logistic, seed=1337, silent=1, subsample=0.8
# [CV]  colsample_bytree=0.7, learning_rate=0.05, max_depth=11, min_child_weight=11, missing=-999, n_estimators=100, nthread=4, objective=binary:logistic, seed=1337, silent=1, subsample=0.8 -  47.1s
# [CV] colsample_bytree=0.7, learning_rate=0.05, max_depth=12, min_child_weight=11, missing=-999, n_estimators=50, nthread=4, objective=binary:logistic, seed=1337, silent=1, subsample=0.8
# [CV]  colsample_bytree=0.7, learning_rate=0.05, max_depth=11, min_child_weight=11, missing=-999, n_estimators=100, nthread=4, objective=binary:logistic, seed=1337, silent=1, subsample=0.8 -  48.4s
# [CV] colsample_bytree=0.7, learning_rate=0.05, max_depth=12, min_child_weight=11, missing=-999, n_estimators=50, nthread=4, objective=binary:logistic, seed=1337, silent=1, subsample=0.8
# [CV]  colsample_bytree=0.7, learning_rate=0.05, max_depth=11, min_child_weight=11, missing=-999, n_estimators=100, nthread=4, objective=binary:logistic, seed=1337, silent=1, subsample=0.8 -  48.3s
# [CV] colsample_bytree=0.7, learning_rate=0.05, max_depth=12, min_child_weight=11, missing=-999, n_estimators=50, nthread=4, objective=binary:logistic, seed=1337, silent=1, subsample=0.8
# [CV]  colsample_bytree=0.7, learning_rate=0.05, max_depth=11, min_child_weight=11, missing=-999, n_estimators=100, nthread=4, objective=binary:logistic, seed=1337, silent=1, subsample=0.8 -  49.6s
# [CV] colsample_bytree=0.7, learning_rate=0.05, max_depth=12, min_child_weight=11, missing=-999, n_estimators=50, nthread=4, objective=binary:logistic, seed=1337, silent=1, subsample=0.8
# [CV]  colsample_bytree=0.7, learning_rate=0.05, max_depth=12, min_child_weight=11, missing=-999, n_estimators=50, nthread=4, objective=binary:logistic, seed=1337, silent=1, subsample=0.8 -  19.6s
# [CV] colsample_bytree=0.7, learning_rate=0.05, max_depth=12, min_child_weight=11, missing=-999, n_estimators=70, nthread=4, objective=binary:logistic, seed=1337, silent=1, subsample=0.8
# [Parallel(n_jobs=5)]: Done  31 tasks      | elapsed:  3.5min
# [CV]  colsample_bytree=0.7, learning_rate=0.05, max_depth=12, min_child_weight=11, missing=-999, n_estimators=50, nthread=4, objective=binary:logistic, seed=1337, silent=1, subsample=0.8 -  20.9s
# [CV] colsample_bytree=0.7, learning_rate=0.05, max_depth=12, min_child_weight=11, missing=-999, n_estimators=70, nthread=4, objective=binary:logistic, seed=1337, silent=1, subsample=0.8
# [CV]  colsample_bytree=0.7, learning_rate=0.05, max_depth=12, min_child_weight=11, missing=-999, n_estimators=50, nthread=4, objective=binary:logistic, seed=1337, silent=1, subsample=0.8 -  20.0s
# [CV] colsample_bytree=0.7, learning_rate=0.05, max_depth=12, min_child_weight=11, missing=-999, n_estimators=70, nthread=4, objective=binary:logistic, seed=1337, silent=1, subsample=0.8
# [CV]  colsample_bytree=0.7, learning_rate=0.05, max_depth=12, min_child_weight=11, missing=-999, n_estimators=50, nthread=4, objective=binary:logistic, seed=1337, silent=1, subsample=0.8 -  20.4s
# [CV] colsample_bytree=0.7, learning_rate=0.05, max_depth=12, min_child_weight=11, missing=-999, n_estimators=70, nthread=4, objective=binary:logistic, seed=1337, silent=1, subsample=0.8
# [CV]  colsample_bytree=0.7, learning_rate=0.05, max_depth=12, min_child_weight=11, missing=-999, n_estimators=50, nthread=4, objective=binary:logistic, seed=1337, silent=1, subsample=0.8 -  19.9s
# [CV] colsample_bytree=0.7, learning_rate=0.05, max_depth=12, min_child_weight=11, missing=-999, n_estimators=70, nthread=4, objective=binary:logistic, seed=1337, silent=1, subsample=0.8
# [CV]  colsample_bytree=0.7, learning_rate=0.05, max_depth=12, min_child_weight=11, missing=-999, n_estimators=70, nthread=4, objective=binary:logistic, seed=1337, silent=1, subsample=0.8 -  30.6s
# [CV] colsample_bytree=0.7, learning_rate=0.05, max_depth=12, min_child_weight=11, missing=-999, n_estimators=100, nthread=4, objective=binary:logistic, seed=1337, silent=1, subsample=0.8
# [CV]  colsample_bytree=0.7, learning_rate=0.05, max_depth=12, min_child_weight=11, missing=-999, n_estimators=70, nthread=4, objective=binary:logistic, seed=1337, silent=1, subsample=0.8 -  30.2s
# [CV] colsample_bytree=0.7, learning_rate=0.05, max_depth=12, min_child_weight=11, missing=-999, n_estimators=100, nthread=4, objective=binary:logistic, seed=1337, silent=1, subsample=0.8
# [CV]  colsample_bytree=0.7, learning_rate=0.05, max_depth=12, min_child_weight=11, missing=-999, n_estimators=70, nthread=4, objective=binary:logistic, seed=1337, silent=1, subsample=0.8 -  30.5s
# [CV] colsample_bytree=0.7, learning_rate=0.05, max_depth=12, min_child_weight=11, missing=-999, n_estimators=100, nthread=4, objective=binary:logistic, seed=1337, silent=1, subsample=0.8
# [CV]  colsample_bytree=0.7, learning_rate=0.05, max_depth=12, min_child_weight=11, missing=-999, n_estimators=70, nthread=4, objective=binary:logistic, seed=1337, silent=1, subsample=0.8 -  30.9s
# [CV] colsample_bytree=0.7, learning_rate=0.05, max_depth=12, min_child_weight=11, missing=-999, n_estimators=100, nthread=4, objective=binary:logistic, seed=1337, silent=1, subsample=0.8
# [CV]  colsample_bytree=0.7, learning_rate=0.05, max_depth=12, min_child_weight=11, missing=-999, n_estimators=70, nthread=4, objective=binary:logistic, seed=1337, silent=1, subsample=0.8 -  31.8s
# [CV] colsample_bytree=0.7, learning_rate=0.05, max_depth=12, min_child_weight=11, missing=-999, n_estimators=100, nthread=4, objective=binary:logistic, seed=1337, silent=1, subsample=0.8
# [CV]  colsample_bytree=0.7, learning_rate=0.05, max_depth=12, min_child_weight=11, missing=-999, n_estimators=100, nthread=4, objective=binary:logistic, seed=1337, silent=1, subsample=0.8 -  36.4s
# [CV]  colsample_bytree=0.7, learning_rate=0.05, max_depth=12, min_child_weight=11, missing=-999, n_estimators=100, nthread=4, objective=binary:logistic, seed=1337, silent=1, subsample=0.8 -  35.8s
# [CV]  colsample_bytree=0.7, learning_rate=0.05, max_depth=12, min_child_weight=11, missing=-999, n_estimators=100, nthread=4, objective=binary:logistic, seed=1337, silent=1, subsample=0.8 -  36.8s
# [CV]  colsample_bytree=0.7, learning_rate=0.05, max_depth=12, min_child_weight=11, missing=-999, n_estimators=100, nthread=4, objective=binary:logistic, seed=1337, silent=1, subsample=0.8 -  36.9s
# [CV]  colsample_bytree=0.7, learning_rate=0.05, max_depth=12, min_child_weight=11, missing=-999, n_estimators=100, nthread=4, objective=binary:logistic, seed=1337, silent=1, subsample=0.8 -  32.6s
# [Parallel(n_jobs=5)]: Done  45 out of  45 | elapsed:  4.7min finished
# GridSearchCV(cv=sklearn.cross_validation.StratifiedKFold(labels=[False False ..., False False], n_folds=5, shuffle=True, random_state=None),
#        error_score='raise',
#        estimator=XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bytree=1, gamma=0, learning_rate=0.1, max_delta_step=0,
#        max_depth=3, min_child_weight=1, missing=None, n_estimators=100,
#        n_jobs=1, nthread=None, objective='binary:logistic', random_state=0,
#        reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#        silent=True, subsample=1),
#        fit_params={}, iid=True, n_jobs=5,
#        param_grid={'nthread': [4], 'objective': ['binary:logistic'], 'learning_rate': [0.05], 'max_depth': [10, 11, 12], 'min_child_weight': [11], 'silent': [1], 'subsample': [0.8], 'colsample_bytree': [0.7], 'n_estimators': [50, 70, 100], 'missing': [-999], 'seed': [1337]},
#        pre_dispatch='2*n_jobs', refit=True, scoring='roc_auc', verbose=2)

# %%
model_C = GridSearchCV(xgb_model, param_grid=parameters, n_jobs=5,
                       cv=StratifiedKFold(cy_train, n_folds=5,shuffle=True),
                       scoring='roc_auc',
                       verbose=2,
                       refit=True)
model_C.fit(cX_train, cy_train)
# Out:
# Fitting 5 folds for each of 9 candidates, totalling 45 fits
# [CV] colsample_bytree=0.7, learning_rate=0.05, max_depth=10, min_child_weight=11, missing=-999, n_estimators=50, nthread=4, objective=binary:logistic, seed=1337, silent=1, subsample=0.8
# [CV] colsample_bytree=0.7, learning_rate=0.05, max_depth=10, min_child_weight=11, missing=-999, n_estimators=50, nthread=4, objective=binary:logistic, seed=1337, silent=1, subsample=0.8
# [CV] colsample_bytree=0.7, learning_rate=0.05, max_depth=10, min_child_weight=11, missing=-999, n_estimators=50, nthread=4, objective=binary:logistic, seed=1337, silent=1, subsample=0.8
# [CV] colsample_bytree=0.7, learning_rate=0.05, max_depth=10, min_child_weight=11, missing=-999, n_estimators=50, nthread=4, objective=binary:logistic, seed=1337, silent=1, subsample=0.8
# [CV] colsample_bytree=0.7, learning_rate=0.05, max_depth=10, min_child_weight=11, missing=-999, n_estimators=50, nthread=4, objective=binary:logistic, seed=1337, silent=1, subsample=0.8
# [CV]  colsample_bytree=0.7, learning_rate=0.05, max_depth=10, min_child_weight=11, missing=-999, n_estimators=50, nthread=4, objective=binary:logistic, seed=1337, silent=1, subsample=0.8 -  21.7s
# [CV] colsample_bytree=0.7, learning_rate=0.05, max_depth=10, min_child_weight=11, missing=-999, n_estimators=70, nthread=4, objective=binary:logistic, seed=1337, silent=1, subsample=0.8
# [CV]  colsample_bytree=0.7, learning_rate=0.05, max_depth=10, min_child_weight=11, missing=-999, n_estimators=50, nthread=4, objective=binary:logistic, seed=1337, silent=1, subsample=0.8 -  22.5s
# [CV] colsample_bytree=0.7, learning_rate=0.05, max_depth=10, min_child_weight=11, missing=-999, n_estimators=70, nthread=4, objective=binary:logistic, seed=1337, silent=1, subsample=0.8
# [CV]  colsample_bytree=0.7, learning_rate=0.05, max_depth=10, min_child_weight=11, missing=-999, n_estimators=50, nthread=4, objective=binary:logistic, seed=1337, silent=1, subsample=0.8 -  22.8s
# [CV] colsample_bytree=0.7, learning_rate=0.05, max_depth=10, min_child_weight=11, missing=-999, n_estimators=70, nthread=4, objective=binary:logistic, seed=1337, silent=1, subsample=0.8
# [CV]  colsample_bytree=0.7, learning_rate=0.05, max_depth=10, min_child_weight=11, missing=-999, n_estimators=50, nthread=4, objective=binary:logistic, seed=1337, silent=1, subsample=0.8 -  24.0s
# [CV] colsample_bytree=0.7, learning_rate=0.05, max_depth=10, min_child_weight=11, missing=-999, n_estimators=70, nthread=4, objective=binary:logistic, seed=1337, silent=1, subsample=0.8
# [CV]  colsample_bytree=0.7, learning_rate=0.05, max_depth=10, min_child_weight=11, missing=-999, n_estimators=50, nthread=4, objective=binary:logistic, seed=1337, silent=1, subsample=0.8 -  24.2s
# [CV] colsample_bytree=0.7, learning_rate=0.05, max_depth=10, min_child_weight=11, missing=-999, n_estimators=70, nthread=4, objective=binary:logistic, seed=1337, silent=1, subsample=0.8
# [CV]  colsample_bytree=0.7, learning_rate=0.05, max_depth=10, min_child_weight=11, missing=-999, n_estimators=70, nthread=4, objective=binary:logistic, seed=1337, silent=1, subsample=0.8 -  39.8s
# [CV] colsample_bytree=0.7, learning_rate=0.05, max_depth=10, min_child_weight=11, missing=-999, n_estimators=100, nthread=4, objective=binary:logistic, seed=1337, silent=1, subsample=0.8
# [CV]  colsample_bytree=0.7, learning_rate=0.05, max_depth=10, min_child_weight=11, missing=-999, n_estimators=70, nthread=4, objective=binary:logistic, seed=1337, silent=1, subsample=0.8 -  38.3s
# [CV] colsample_bytree=0.7, learning_rate=0.05, max_depth=10, min_child_weight=11, missing=-999, n_estimators=100, nthread=4, objective=binary:logistic, seed=1337, silent=1, subsample=0.8
# [CV]  colsample_bytree=0.7, learning_rate=0.05, max_depth=10, min_child_weight=11, missing=-999, n_estimators=70, nthread=4, objective=binary:logistic, seed=1337, silent=1, subsample=0.8 -  41.4s
# [CV] colsample_bytree=0.7, learning_rate=0.05, max_depth=10, min_child_weight=11, missing=-999, n_estimators=100, nthread=4, objective=binary:logistic, seed=1337, silent=1, subsample=0.8
# [CV]  colsample_bytree=0.7, learning_rate=0.05, max_depth=10, min_child_weight=11, missing=-999, n_estimators=70, nthread=4, objective=binary:logistic, seed=1337, silent=1, subsample=0.8 -  40.3s
# [CV] colsample_bytree=0.7, learning_rate=0.05, max_depth=10, min_child_weight=11, missing=-999, n_estimators=100, nthread=4, objective=binary:logistic, seed=1337, silent=1, subsample=0.8
# [CV]  colsample_bytree=0.7, learning_rate=0.05, max_depth=10, min_child_weight=11, missing=-999, n_estimators=70, nthread=4, objective=binary:logistic, seed=1337, silent=1, subsample=0.8 -  41.7s
# [CV] colsample_bytree=0.7, learning_rate=0.05, max_depth=10, min_child_weight=11, missing=-999, n_estimators=100, nthread=4, objective=binary:logistic, seed=1337, silent=1, subsample=0.8
# [CV]  colsample_bytree=0.7, learning_rate=0.05, max_depth=10, min_child_weight=11, missing=-999, n_estimators=100, nthread=4, objective=binary:logistic, seed=1337, silent=1, subsample=0.8 -  59.6s
# [CV] colsample_bytree=0.7, learning_rate=0.05, max_depth=11, min_child_weight=11, missing=-999, n_estimators=50, nthread=4, objective=binary:logistic, seed=1337, silent=1, subsample=0.8
# [CV]  colsample_bytree=0.7, learning_rate=0.05, max_depth=10, min_child_weight=11, missing=-999, n_estimators=100, nthread=4, objective=binary:logistic, seed=1337, silent=1, subsample=0.8 -  56.9s
# [CV] colsample_bytree=0.7, learning_rate=0.05, max_depth=11, min_child_weight=11, missing=-999, n_estimators=50, nthread=4, objective=binary:logistic, seed=1337, silent=1, subsample=0.8
# [CV]  colsample_bytree=0.7, learning_rate=0.05, max_depth=10, min_child_weight=11, missing=-999, n_estimators=100, nthread=4, objective=binary:logistic, seed=1337, silent=1, subsample=0.8 - 1.0min
# [CV] colsample_bytree=0.7, learning_rate=0.05, max_depth=11, min_child_weight=11, missing=-999, n_estimators=50, nthread=4, objective=binary:logistic, seed=1337, silent=1, subsample=0.8
# [CV]  colsample_bytree=0.7, learning_rate=0.05, max_depth=10, min_child_weight=11, missing=-999, n_estimators=100, nthread=4, objective=binary:logistic, seed=1337, silent=1, subsample=0.8 -  59.2s
# [CV] colsample_bytree=0.7, learning_rate=0.05, max_depth=11, min_child_weight=11, missing=-999, n_estimators=50, nthread=4, objective=binary:logistic, seed=1337, silent=1, subsample=0.8
# [CV]  colsample_bytree=0.7, learning_rate=0.05, max_depth=10, min_child_weight=11, missing=-999, n_estimators=100, nthread=4, objective=binary:logistic, seed=1337, silent=1, subsample=0.8 - 1.0min
# [CV] colsample_bytree=0.7, learning_rate=0.05, max_depth=11, min_child_weight=11, missing=-999, n_estimators=50, nthread=4, objective=binary:logistic, seed=1337, silent=1, subsample=0.8
# [CV]  colsample_bytree=0.7, learning_rate=0.05, max_depth=11, min_child_weight=11, missing=-999, n_estimators=50, nthread=4, objective=binary:logistic, seed=1337, silent=1, subsample=0.8 -  34.1s
# [CV] colsample_bytree=0.7, learning_rate=0.05, max_depth=11, min_child_weight=11, missing=-999, n_estimators=70, nthread=4, objective=binary:logistic, seed=1337, silent=1, subsample=0.8
# [CV]  colsample_bytree=0.7, learning_rate=0.05, max_depth=11, min_child_weight=11, missing=-999, n_estimators=50, nthread=4, objective=binary:logistic, seed=1337, silent=1, subsample=0.8 -  35.7s
# [CV] colsample_bytree=0.7, learning_rate=0.05, max_depth=11, min_child_weight=11, missing=-999, n_estimators=70, nthread=4, objective=binary:logistic, seed=1337, silent=1, subsample=0.8
# [CV]  colsample_bytree=0.7, learning_rate=0.05, max_depth=11, min_child_weight=11, missing=-999, n_estimators=50, nthread=4, objective=binary:logistic, seed=1337, silent=1, subsample=0.8 -  34.4s
# [CV] colsample_bytree=0.7, learning_rate=0.05, max_depth=11, min_child_weight=11, missing=-999, n_estimators=70, nthread=4, objective=binary:logistic, seed=1337, silent=1, subsample=0.8
# [CV]  colsample_bytree=0.7, learning_rate=0.05, max_depth=11, min_child_weight=11, missing=-999, n_estimators=50, nthread=4, objective=binary:logistic, seed=1337, silent=1, subsample=0.8 -  32.4s
# [CV] colsample_bytree=0.7, learning_rate=0.05, max_depth=11, min_child_weight=11, missing=-999, n_estimators=70, nthread=4, objective=binary:logistic, seed=1337, silent=1, subsample=0.8
# [CV]  colsample_bytree=0.7, learning_rate=0.05, max_depth=11, min_child_weight=11, missing=-999, n_estimators=50, nthread=4, objective=binary:logistic, seed=1337, silent=1, subsample=0.8 -  35.9s
# [CV] colsample_bytree=0.7, learning_rate=0.05, max_depth=11, min_child_weight=11, missing=-999, n_estimators=70, nthread=4, objective=binary:logistic, seed=1337, silent=1, subsample=0.8
# [CV]  colsample_bytree=0.7, learning_rate=0.05, max_depth=11, min_child_weight=11, missing=-999, n_estimators=70, nthread=4, objective=binary:logistic, seed=1337, silent=1, subsample=0.8 -  43.5s
# [CV] colsample_bytree=0.7, learning_rate=0.05, max_depth=11, min_child_weight=11, missing=-999, n_estimators=100, nthread=4, objective=binary:logistic, seed=1337, silent=1, subsample=0.8
# [CV]  colsample_bytree=0.7, learning_rate=0.05, max_depth=11, min_child_weight=11, missing=-999, n_estimators=70, nthread=4, objective=binary:logistic, seed=1337, silent=1, subsample=0.8 -  42.2s
# [CV] colsample_bytree=0.7, learning_rate=0.05, max_depth=11, min_child_weight=11, missing=-999, n_estimators=100, nthread=4, objective=binary:logistic, seed=1337, silent=1, subsample=0.8
# [CV]  colsample_bytree=0.7, learning_rate=0.05, max_depth=11, min_child_weight=11, missing=-999, n_estimators=70, nthread=4, objective=binary:logistic, seed=1337, silent=1, subsample=0.8 -  44.4s
# [CV] colsample_bytree=0.7, learning_rate=0.05, max_depth=11, min_child_weight=11, missing=-999, n_estimators=100, nthread=4, objective=binary:logistic, seed=1337, silent=1, subsample=0.8
# [CV]  colsample_bytree=0.7, learning_rate=0.05, max_depth=11, min_child_weight=11, missing=-999, n_estimators=70, nthread=4, objective=binary:logistic, seed=1337, silent=1, subsample=0.8 -  45.7s
# [CV] colsample_bytree=0.7, learning_rate=0.05, max_depth=11, min_child_weight=11, missing=-999, n_estimators=100, nthread=4, objective=binary:logistic, seed=1337, silent=1, subsample=0.8
# [CV]  colsample_bytree=0.7, learning_rate=0.05, max_depth=11, min_child_weight=11, missing=-999, n_estimators=70, nthread=4, objective=binary:logistic, seed=1337, silent=1, subsample=0.8 -  45.4s
# [CV] colsample_bytree=0.7, learning_rate=0.05, max_depth=11, min_child_weight=11, missing=-999, n_estimators=100, nthread=4, objective=binary:logistic, seed=1337, silent=1, subsample=0.8
# [CV]  colsample_bytree=0.7, learning_rate=0.05, max_depth=11, min_child_weight=11, missing=-999, n_estimators=100, nthread=4, objective=binary:logistic, seed=1337, silent=1, subsample=0.8 -  39.5s
# [CV] colsample_bytree=0.7, learning_rate=0.05, max_depth=12, min_child_weight=11, missing=-999, n_estimators=50, nthread=4, objective=binary:logistic, seed=1337, silent=1, subsample=0.8
# [CV]  colsample_bytree=0.7, learning_rate=0.05, max_depth=11, min_child_weight=11, missing=-999, n_estimators=100, nthread=4, objective=binary:logistic, seed=1337, silent=1, subsample=0.8 -  35.7s
# [CV] colsample_bytree=0.7, learning_rate=0.05, max_depth=12, min_child_weight=11, missing=-999, n_estimators=50, nthread=4, objective=binary:logistic, seed=1337, silent=1, subsample=0.8
# [CV]  colsample_bytree=0.7, learning_rate=0.05, max_depth=11, min_child_weight=11, missing=-999, n_estimators=100, nthread=4, objective=binary:logistic, seed=1337, silent=1, subsample=0.8 -  37.1s
# [CV] colsample_bytree=0.7, learning_rate=0.05, max_depth=12, min_child_weight=11, missing=-999, n_estimators=50, nthread=4, objective=binary:logistic, seed=1337, silent=1, subsample=0.8
# [CV]  colsample_bytree=0.7, learning_rate=0.05, max_depth=11, min_child_weight=11, missing=-999, n_estimators=100, nthread=4, objective=binary:logistic, seed=1337, silent=1, subsample=0.8 -  38.7s
# [CV] colsample_bytree=0.7, learning_rate=0.05, max_depth=12, min_child_weight=11, missing=-999, n_estimators=50, nthread=4, objective=binary:logistic, seed=1337, silent=1, subsample=0.8
# [CV]  colsample_bytree=0.7, learning_rate=0.05, max_depth=11, min_child_weight=11, missing=-999, n_estimators=100, nthread=4, objective=binary:logistic, seed=1337, silent=1, subsample=0.8 -  38.4s
# [CV] colsample_bytree=0.7, learning_rate=0.05, max_depth=12, min_child_weight=11, missing=-999, n_estimators=50, nthread=4, objective=binary:logistic, seed=1337, silent=1, subsample=0.8
# [CV]  colsample_bytree=0.7, learning_rate=0.05, max_depth=12, min_child_weight=11, missing=-999, n_estimators=50, nthread=4, objective=binary:logistic, seed=1337, silent=1, subsample=0.8 -  16.9s
# [CV] colsample_bytree=0.7, learning_rate=0.05, max_depth=12, min_child_weight=11, missing=-999, n_estimators=70, nthread=4, objective=binary:logistic, seed=1337, silent=1, subsample=0.8
# [Parallel(n_jobs=5)]: Done  31 tasks      | elapsed:  4.3min
# [CV]  colsample_bytree=0.7, learning_rate=0.05, max_depth=12, min_child_weight=11, missing=-999, n_estimators=50, nthread=4, objective=binary:logistic, seed=1337, silent=1, subsample=0.8 -  16.3s
# [CV]  colsample_bytree=0.7, learning_rate=0.05, max_depth=12, min_child_weight=11, missing=-999, n_estimators=50, nthread=4, objective=binary:logistic, seed=1337, silent=1, subsample=0.8 -  18.1s
# [CV] colsample_bytree=0.7, learning_rate=0.05, max_depth=12, min_child_weight=11, missing=-999, n_estimators=70, nthread=4, objective=binary:logistic, seed=1337, silent=1, subsample=0.8
# [CV] colsample_bytree=0.7, learning_rate=0.05, max_depth=12, min_child_weight=11, missing=-999, n_estimators=70, nthread=4, objective=binary:logistic, seed=1337, silent=1, subsample=0.8
# [CV]  colsample_bytree=0.7, learning_rate=0.05, max_depth=12, min_child_weight=11, missing=-999, n_estimators=50, nthread=4, objective=binary:logistic, seed=1337, silent=1, subsample=0.8 -  17.3s
# [CV] colsample_bytree=0.7, learning_rate=0.05, max_depth=12, min_child_weight=11, missing=-999, n_estimators=70, nthread=4, objective=binary:logistic, seed=1337, silent=1, subsample=0.8
# [CV]  colsample_bytree=0.7, learning_rate=0.05, max_depth=12, min_child_weight=11, missing=-999, n_estimators=50, nthread=4, objective=binary:logistic, seed=1337, silent=1, subsample=0.8 -  18.5s
# [CV] colsample_bytree=0.7, learning_rate=0.05, max_depth=12, min_child_weight=11, missing=-999, n_estimators=70, nthread=4, objective=binary:logistic, seed=1337, silent=1, subsample=0.8
# [CV]  colsample_bytree=0.7, learning_rate=0.05, max_depth=12, min_child_weight=11, missing=-999, n_estimators=70, nthread=4, objective=binary:logistic, seed=1337, silent=1, subsample=0.8 -  26.9s
# [CV] colsample_bytree=0.7, learning_rate=0.05, max_depth=12, min_child_weight=11, missing=-999, n_estimators=100, nthread=4, objective=binary:logistic, seed=1337, silent=1, subsample=0.8
# [CV]  colsample_bytree=0.7, learning_rate=0.05, max_depth=12, min_child_weight=11, missing=-999, n_estimators=70, nthread=4, objective=binary:logistic, seed=1337, silent=1, subsample=0.8 -  25.6s
# [CV] colsample_bytree=0.7, learning_rate=0.05, max_depth=12, min_child_weight=11, missing=-999, n_estimators=100, nthread=4, objective=binary:logistic, seed=1337, silent=1, subsample=0.8
# [CV]  colsample_bytree=0.7, learning_rate=0.05, max_depth=12, min_child_weight=11, missing=-999, n_estimators=70, nthread=4, objective=binary:logistic, seed=1337, silent=1, subsample=0.8 -  27.0s
# [CV] colsample_bytree=0.7, learning_rate=0.05, max_depth=12, min_child_weight=11, missing=-999, n_estimators=100, nthread=4, objective=binary:logistic, seed=1337, silent=1, subsample=0.8
# [CV]  colsample_bytree=0.7, learning_rate=0.05, max_depth=12, min_child_weight=11, missing=-999, n_estimators=70, nthread=4, objective=binary:logistic, seed=1337, silent=1, subsample=0.8 -  27.7s
# [CV] colsample_bytree=0.7, learning_rate=0.05, max_depth=12, min_child_weight=11, missing=-999, n_estimators=100, nthread=4, objective=binary:logistic, seed=1337, silent=1, subsample=0.8
# [CV]  colsample_bytree=0.7, learning_rate=0.05, max_depth=12, min_child_weight=11, missing=-999, n_estimators=70, nthread=4, objective=binary:logistic, seed=1337, silent=1, subsample=0.8 -  27.9s
# [CV] colsample_bytree=0.7, learning_rate=0.05, max_depth=12, min_child_weight=11, missing=-999, n_estimators=100, nthread=4, objective=binary:logistic, seed=1337, silent=1, subsample=0.8
# [CV]  colsample_bytree=0.7, learning_rate=0.05, max_depth=12, min_child_weight=11, missing=-999, n_estimators=100, nthread=4, objective=binary:logistic, seed=1337, silent=1, subsample=0.8 -  34.0s
# [CV]  colsample_bytree=0.7, learning_rate=0.05, max_depth=12, min_child_weight=11, missing=-999, n_estimators=100, nthread=4, objective=binary:logistic, seed=1337, silent=1, subsample=0.8 -  32.1s
# [CV]  colsample_bytree=0.7, learning_rate=0.05, max_depth=12, min_child_weight=11, missing=-999, n_estimators=100, nthread=4, objective=binary:logistic, seed=1337, silent=1, subsample=0.8 -  33.0s
# [CV]  colsample_bytree=0.7, learning_rate=0.05, max_depth=12, min_child_weight=11, missing=-999, n_estimators=100, nthread=4, objective=binary:logistic, seed=1337, silent=1, subsample=0.8 -  33.9s
# [CV]  colsample_bytree=0.7, learning_rate=0.05, max_depth=12, min_child_weight=11, missing=-999, n_estimators=100, nthread=4, objective=binary:logistic, seed=1337, silent=1, subsample=0.8 -  33.8s
# [Parallel(n_jobs=5)]: Done  45 out of  45 | elapsed:  5.3min finished
# GridSearchCV(cv=sklearn.cross_validation.StratifiedKFold(labels=[False  True ..., False False], n_folds=5, shuffle=True, random_state=None),
#        error_score='raise',
#        estimator=XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bytree=1, gamma=0, learning_rate=0.1, max_delta_step=0,
#        max_depth=3, min_child_weight=1, missing=None, n_estimators=100,
#        n_jobs=1, nthread=None, objective='binary:logistic', random_state=0,
#        reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#        silent=True, subsample=1),
#        fit_params={}, iid=True, n_jobs=5,
#        param_grid={'nthread': [4], 'objective': ['binary:logistic'], 'learning_rate': [0.05], 'max_depth': [10, 11, 12], 'min_child_weight': [11], 'silent': [1], 'subsample': [0.8], 'colsample_bytree': [0.7], 'n_estimators': [50, 70, 100], 'missing': [-999], 'seed': [1337]},
#        pre_dispatch='2*n_jobs', refit=True, scoring='roc_auc', verbose=2)

# %% [markdown]
# 查看最优参数组合

# %%
best_parameters, score, _ = max(model_B.grid_scores_, key=lambda x:x[1])
print('Raw ACU score', score)

for param_name in sorted(best_parameters.keys()):
    print("%s: %r"%(param_name, best_parameters[param_name]))
# Out:
# Raw ACU score 0.8264430361413347
# colsample_bytree: 0.7
# learning_rate: 0.05
# max_depth: 10
# min_child_weight: 11
# missing: -999
# n_estimators: 100
# nthread: 4
# objective: 'binary:logistic'
# seed: 1337
# silent: 1
# subsample: 0.8

# %%
a_test = pd.read_csv(data_path['A']['test'], index_col='id')
b_test = pd.read_csv(data_path['B']['test'], index_col='id')
c_test = pd.read_csv(data_path['C']['test'], index_col='id')

# %%
a_test = pre_process_data(a_test, enforce_cols=aX_train.columns)
b_test = pre_process_data(b_test, enforce_cols=bX_train.columns)
c_test = pre_process_data(c_test, enforce_cols=cX_train.columns)
# Out:
# Input shape:	(4041, 344)
# After standardization (4041, 344)
# After converting categoricals:	(4041, 851)
# Input shape:	(1604, 441)
# After standardization (1604, 441)
# After converting categoricals:	(1604, 1419)
# Input shape:	(3187, 163)
# After standardization (3187, 163)
# After converting categoricals:	(3187, 773)

# %% [markdown]
# 因为crossvalidation之后，feature的顺序会发生变化，导致test和train的feature顺序不一致，所以在这里我把feature的顺序调整了一下

# %%
def order(df_test, df_train):
    new_df = pd.DataFrame()
    for key in df_train:
        new_df[key] = df_test[key]
    return new_df

# %%
a_test = order(a_test, aX_train)
b_test = order(b_test, bX_train)
c_test = order(c_test, cX_train)

# %%
a_test.head()
# Out:
#        nEsgxvAq  OMtioXZZ  YFMZwKrU  TiwRslOh  wBXbHZmp_DkQlr  wBXbHZmp_JhtDR  \
# id
# 418    0.580509 -0.519164 -0.027227 -1.095034               0               1
# 41249  0.580509  1.183020  1.062118  0.730851               0               1
# 16205 -0.361216  0.331928  1.062118 -1.551505               0               1
# 97501  0.580509  1.183020  1.062118  1.643794               0               1
# 67756 -1.302941  1.183020 -0.027227 -0.638563               0               1
#
#        SlDKnCuu_GUusz  SlDKnCuu_alLXR  KAJOWiiw_BIZns  KAJOWiiw_TuovO  \
# id
# 418                 1               0               0               1
# 41249               0               1               1               0
# 16205               0               1               1               0
# 97501               0               1               1               0
# 67756               1               0               1               0
#
#             ...        JCDeZBXq_LPtkN  JCDeZBXq_UyAms  HGPWuGlV_WKNwg  \
# id          ...
# 418         ...                     0               1               0
# 41249       ...                     0               1               0
# 16205       ...                     0               1               0
# 97501       ...                     0               1               0
# 67756       ...                     0               1               0
#
#        HGPWuGlV_vkbkA  GDUPaBQs_qCEuA  GDUPaBQs_qQxrL  WuwrCsIY_AITFl  \
# id
# 418                 1               0               1               0
# 41249               1               0               1               1
# 16205               1               0               1               1
# 97501               1               0               1               1
# 67756               1               0               1               1
#
#        WuwrCsIY_GAZGl  AlDbXTlZ_aQeIm  AlDbXTlZ_cecIq
# id
# 418                 1               0               1
# 41249               0               1               0
# 16205               0               1               0
# 97501               0               0               1
# 67756               0               0               1
#
# [5 rows x 858 columns]

# %%
aX_train.head()
# Out:
#        nEsgxvAq  OMtioXZZ  YFMZwKrU  TiwRslOh  wBXbHZmp_DkQlr  wBXbHZmp_JhtDR  \
# id
# 46107 -1.447160  0.325746  1.099716 -0.628045               0               1
# 82739 -0.414625 -0.503468 -0.016050  0.713467               0               1
# 9646   0.617910 -0.503468 -0.016050 -0.628045               0               1
# 10975  0.617910 -1.332682 -1.131816  0.713467               0               1
# 16463  0.617910  0.325746 -1.131816 -0.180874               0               1
#
#        SlDKnCuu_GUusz  SlDKnCuu_alLXR  KAJOWiiw_BIZns  KAJOWiiw_TuovO  \
# id
# 46107               1               0               0               1
# 82739               1               0               0               1
# 9646                1               0               1               0
# 10975               1               0               0               1
# 16463               0               1               0               1
#
#             ...        JCDeZBXq_LPtkN  JCDeZBXq_UyAms  HGPWuGlV_WKNwg  \
# id          ...
# 46107       ...                     1               0               0
# 82739       ...                     0               1               0
# 9646        ...                     0               1               0
# 10975       ...                     0               1               0
# 16463       ...                     0               1               0
#
#        HGPWuGlV_vkbkA  GDUPaBQs_qCEuA  GDUPaBQs_qQxrL  WuwrCsIY_AITFl  \
# id
# 46107               1               0               1               1
# 82739               1               0               1               1
# 9646                1               0               1               1
# 10975               1               0               1               1
# 16463               1               0               1               0
#
#        WuwrCsIY_GAZGl  AlDbXTlZ_aQeIm  AlDbXTlZ_cecIq
# id
# 46107               0               1               0
# 82739               0               0               1
# 9646                0               0               1
# 10975               0               0               1
# 16463               1               1               0
#
# [5 rows x 858 columns]

# %%
a_preds = model_A.predict_proba(a_test)
b_preds = model_B.predict_proba(b_test)
c_preds = model_C.predict_proba(c_test)

# %%
def make_country_sub(preds, test_feat, country):
    # make sure we code the country correctly
    country_codes = ['A', 'B', 'C']
    
    # get just the poor probabilities
    country_sub = pd.DataFrame(data=preds[:, 1],  # proba p=1
                               columns=['poor'], 
                               index=test_feat.index)

    
    # add the country code for joining later
    country_sub["country"] = country
    return country_sub[["country", "poor"]]

# %%
# convert preds to data frames
a_sub = make_country_sub(a_preds, a_test, 'A')
b_sub = make_country_sub(b_preds, b_test, 'B')
c_sub = make_country_sub(c_preds, c_test, 'C')

# %%
submission = pd.concat([a_sub, b_sub, c_sub])

# %%
submission.tail()
# Out:
#       country      poor
# id
# 6775        C  0.005753
# 88300       C  0.004832
# 35424       C  0.007010
# 81668       C  0.005411
# 98377       C  0.007171

# %%
submission.to_csv('submission.csv')
